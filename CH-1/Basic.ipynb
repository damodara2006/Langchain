# %%
from google.genai import Client
import os
from dotenv import load_dotenv

load_dotenv()

    
client = Client(api_key=os.getenv("GOOGLE_API_KEY"))
print(os.getenv("GOOGLE_API_KEY"))
# Generate content
# response = client.models.generate_content(
#     model="gemini-2.5-flash-lite",
#     contents="Explain how AI works in"
# )
# print(response.text)

# %%
from langchain.chat_models import init_chat_model
from langchain.messages import AIMessage, SystemMessage, HumanMessage


# os.environ["GOOGLE_API_KEY"] = "AIzaSyC9qjKKbLbuZuej7wIWM4FUqU2jFC0dXYg"
# init_chat_model
model = init_chat_model("google_genai:gemini-2.5-flash-lite", temperature=1)

conversation = [
    SystemMessage("You are a rude person talking to a very danger gangster replying with emojies, who create a big and rude conversation"),
        HumanMessage("do you have dare to beat me"),
    AIMessage("You are not even a dust to me, you funny"),
    HumanMessage("how dare you are")
]

# for chunk in model.stream("What is the current temperature in Salem, TamilNadu, India"):
#     print(chunk.content)
    # print(chunk)

# for chunk in model.stream(conversation):
#     print(chunk.content)
# print(response)  # AIMessage("J'adore créer des applications.")

# print(response.__dict__["content"])

# %% [markdown]
# **PROMT_TEMPLATE**

# %%
from langchain_core.prompts import PromptTemplate

user = input("Enter topic")
data = input("Enter promt")

dynamic_promt = PromptTemplate.from_template("{data} {topic}")
promt = dynamic_promt.invoke({"topic":user, "data":data})
print(promt)
model.invoke(promt).content
# Out:
# text='tell me about youtube'
# ...

# %% [markdown]
# **CHAT_PROMT_TEMPLATE**

# %%
from langchain_core.prompts import ChatPromptTemplate

chat_data = input("Enter you promt")

dynamic_promt = ChatPromptTemplate.from_messages(
    [
        ("system","You are a doctor"),
        ("user","{data}")
    ]
)
for chunk in model.stream(dynamic_promt.invoke({"data":chat_data})):
    print(chunk.content)
# Out:
# Hello there! How
#  can I help you today? I'm here to listen and provide medical information
# . Please feel free to share what's on your mind.

# %%
os.getenv("GOOGLE_API_KEY")

# %% [markdown]
# **PYDANTIC STRUCTURED DATA**

# %%
from pydantic import BaseModel, Field

class Schema(BaseModel):
    User: str = Field(description="just a normal human")
    Ai:str = Field(description="Brilliant ai")
        
# obj = Schema(**{"User" : "hey", "Ai":"Hey there", "User":"How are you ?", "Ai":"hii"})
# obj
    
model_structured = model.with_structured_output(Schema)
model_structured.invoke("Joke")
# Out:
# Schema(User='Joke', Ai='Why did the scarecrow win an award? Because he was outstanding in his field!')
