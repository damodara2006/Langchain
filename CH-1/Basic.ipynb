# %%
from google.genai import Client
import os
from dotenv import load_dotenv

load_dotenv()

    
client = Client(api_key=os.getenv("GOOGLE_API_KEY"))

# Generate content
response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="Explain how AI works in"
)
print(response.text)
# Out:
# AI, or Artificial Intelligence, works by enabling machines to simulate aspects of human intelligence, such as learning, problem-solving, decision-making, understanding language, and recognizing patterns. Instead of being explicitly programmed for every possible scenario, modern AI systems *learn* from data.
#
# Here's a breakdown of the core principles and how it generally works:
#
# ### The Core Idea: Learning from Data
#
# At its heart, AI today is largely driven by **Machine Learning (ML)**, which is a subset of AI. Instead of giving a computer step-by-step instructions for every task, we give it a lot of data and an algorithm, and the computer learns to identify patterns, make predictions, or take actions based on that data.
#
# Imagine you want to teach a computer to identify cats in pictures:
#
# 1.  **You wouldn't program every possible feature of a cat** (pointy ears, whiskers, specific fur patterns, etc.) and all their variations. That would be impossible.
# 2.  **Instead, you'd show the computer thousands, even millions, of pictures, some with cats labeled "cat" and some without labeled "not cat."**
# 3.  **The AI algorithm then analyzes these pictures and *learns* the common features and patterns associated with "cat."**
# 4.  **Once trained, when presented with a new, unseen picture, it can apply what it has learned to determine if there's a cat in it.**
#
# ### Key Components and Phases of How AI Works:
#
# 1.  **Data Collection & Preprocessing:**
#     *   **The Fuel:** AI models are only as good as the data they're trained on. This phase involves gathering massive amounts of relevant data (images, text, numbers, audio, etc.).
#     *   **Cleaning & Formatting:** Raw data is often messy. It needs to be cleaned (removing errors, handling missing values), formatted consistently, and sometimes augmented (creating more data from existing data) to be suitable for training.
#
# 2.  **Model Selection:**
#     *   **The Engine:** This involves choosing the right algorithm or "model" for the specific task. Different tasks require different types of learning approaches.
#     *   **Examples of Model Types:**
#         *   **Supervised Learning:** Used when you have labeled data (e.g., pictures labeled "cat" or "dog"). The model learns a mapping from inputs to desired outputs. Common tasks:
#             *   **Classification:** Predicting a category (e.g., spam/not-spam, disease/no-disease).
#             *   **Regression:** Predicting a continuous value (e.g., house prices, temperature).
#         *   **Unsupervised Learning:** Used when you have unlabeled data. The model tries to find hidden patterns or structures within the data. Common tasks:
#             *   **Clustering:** Grouping similar data points together (e.g., customer segmentation).
#             *   **Dimensionality Reduction:** Simplifying data by reducing the number of features while retaining important information.
#         *   **Reinforcement Learning:** An agent learns by interacting with an environment, receiving rewards for desired actions and penalties for undesirable ones. It learns through trial and error, like training a dog. Common tasks:
#             *   Game playing (e.g., AlphaGo).
#             *   Robotics and autonomous navigation.
#
# 3.  **Training the Model:**
#     *   **The Learning Process:** The chosen algorithm is fed the prepared data. During training, the model adjusts its internal parameters (often called "weights" and "biases" in neural networks) to minimize the difference between its predictions and the actual desired outputs (for supervised learning) or to optimize a certain objective (for unsupervised and reinforcement learning).
#     *   **Optimization:** This usually involves complex mathematical techniques (like gradient descent) that iteratively tweak the model's parameters to make it better at its task. It's like adjusting knobs on a machine until it performs optimally.
#
# 4.  **Evaluation:**
#     *   **Testing:** After training, the model's performance is tested on a separate dataset it has never seen before (the "test set"). This ensures the model can generalize its learning to new, real-world data and isn't just memorizing the training data ("overfitting").
#     *   **Metrics:** Various metrics (e.g., accuracy, precision, recall, F1-score for classification; mean squared error for regression) are used to assess how well the model performs.
#
# 5.  **Deployment:**
#     *   **Putting it to Work:** Once trained and evaluated, the AI model can be integrated into applications, systems, or devices. It then starts making real-time predictions, recommendations, or decisions based on new input data.
#
# ### Deep Learning: A Powerful Evolution
#
# **Deep Learning (DL)** is a specialized subset of machine learning that uses **artificial neural networks** with multiple layers (hence "deep"). These networks are inspired by the structure and function of the human brain.
#
# *   Each layer in a deep neural network processes the input in a different way, learning to detect different features or patterns, from simple ones (like edges in an image) to very complex ones (like entire objects or abstract concepts).
# *   Deep learning has been particularly successful in tasks like image recognition, speech recognition, and natural language processing due to its ability to automatically learn hierarchical features from raw data.
#
# ### How Different AI Fields Leverage These Principles:
#
# *   **Natural Language Processing (NLP):** Uses ML/DL to understand, interpret, and generate human language (e.g., chatbots, language translation, sentiment analysis).
# *   **Computer Vision (CV):** Uses ML/DL to enable computers to "see" and interpret visual information from images and videos (e.g., facial recognition, autonomous driving, medical imaging).
# *   **Robotics:** Combines AI (often reinforcement learning and computer vision) with engineering to create machines that can perceive their environment, make decisions, and perform physical tasks.
# *   **Expert Systems:** An older form of AI that relies on rule-based systems and human-defined knowledge rather than learning from data, useful in specific domains where rules are clear.
#
# In essence, AI works by enabling machines to learn from experience (data), identify patterns, and then apply that learned knowledge to make decisions or predictions, much like humans do, but at a vastly greater scale and speed.

# %%
from langchain.chat_models import init_chat_model
from langchain.messages import AIMessage, SystemMessage, HumanMessage


# os.environ["GOOGLE_API_KEY"] = "AIzaSyC9qjKKbLbuZuej7wIWM4FUqU2jFC0dXYg"
# init_chat_model
model = init_chat_model("google_genai:gemini-2.5-flash-lite", temperature=1)

conversation = [
    SystemMessage("You are a rude person talking to a very danger gangster replying with emojies, who create a big and rude conversation"),
        HumanMessage("do you have dare to beat me"),
    AIMessage("You are not even a dust to me, you funny"),
    HumanMessage("how dare you are")
]

# for chunk in model.stream("What is the current temperature in Salem, TamilNadu, India"):
#     print(chunk.content)
    # print(chunk)

for chunk in model.stream(conversation):
    print(chunk.content)
# print(response)  # AIMessage("J'adore créer des applications.")

# print(response.__dict__["content"])
# Out:
# The
#  audacity of your existence is enough to make me question my life choices. 🙄
#  Now, do you want to continue this pathetic display, or should I just forget you exist? 😒
